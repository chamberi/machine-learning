# %% [markdown]
# ## Imperfect Data: Cleaning and Analyzing NYC SAT for 2012 Graduating HS Seniors

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
sat = pd.read_csv("../SAT_Results.csv")

# %%
sat
# Out:
#         DBN                                        SCHOOL NAME  \
# 0    01M292      HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL
# 3    01M458                          FORSYTH SATELLITE ACADEMY
# 4    01M509                            MARTA VALLE HIGH SCHOOL
# 5    01M515            LOWER EAST SIDE PREPARATORY HIGH SCHOOL
# 6    01M539  NEW EXPLORATIONS INTO SCIENCE, TECHNOLOGY AND ...
# 7    01M650                               CASCADES HIGH SCHOOL
# 8    01M696                     BARD HIGH SCHOOL EARLY COLLEGE
# 9    02M047  47 THE AMERICAN SIGN LANGUAGE AND ENGLISH SECO...
# 10   02M288                       FOOD AND FINANCE HIGH SCHOOL
# 11   02M294                               ESSEX STREET ACADEMY
# 12   02M296              HIGH SCHOOL OF HOSPITALITY MANAGEMENT
# 13   02M298                                   PACE HIGH SCHOOL
# ...

# %%
sat.columns
# Out:
# Index(['DBN', 'SCHOOL NAME', 'Num of SAT Test Takers',
#        'SAT Critical Reading Avg. Score', 'SAT Math Avg. Score',
#        'SAT Writing Avg. Score'],
#       dtype='object')

# %%
sat.columns = ['DBD', 'NAME', 'Num', 'Read', 'Math', 'Write']

# %%
sat.columns
# Out:
# Index(['DBD', 'NAME', 'Num', 'Read', 'Math', 'Write'], dtype='object')

# %%
sat
# Out:
#         DBD                                               NAME  Num Read Math  \
# 0    01M292      HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES   29  355  404
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL   91  383  423
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL   70  377  402
# 3    01M458                          FORSYTH SATELLITE ACADEMY    7  414  401
# 4    01M509                            MARTA VALLE HIGH SCHOOL   44  390  433
# 5    01M515            LOWER EAST SIDE PREPARATORY HIGH SCHOOL  112  332  557
# 6    01M539  NEW EXPLORATIONS INTO SCIENCE, TECHNOLOGY AND ...  159  522  574
# 7    01M650                               CASCADES HIGH SCHOOL   18  417  418
# 8    01M696                     BARD HIGH SCHOOL EARLY COLLEGE  130  624  604
# 9    02M047  47 THE AMERICAN SIGN LANGUAGE AND ENGLISH SECO...   16  395  400
# 10   02M288                       FOOD AND FINANCE HIGH SCHOOL   62  409  393
# ...

# %%
cs = sat[sat.Num != "s"]

# %%
cs
# Out:
#         DBD                                               NAME  Num Read Math  \
# 0    01M292      HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES   29  355  404
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL   91  383  423
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL   70  377  402
# 3    01M458                          FORSYTH SATELLITE ACADEMY    7  414  401
# 4    01M509                            MARTA VALLE HIGH SCHOOL   44  390  433
# 5    01M515            LOWER EAST SIDE PREPARATORY HIGH SCHOOL  112  332  557
# 6    01M539  NEW EXPLORATIONS INTO SCIENCE, TECHNOLOGY AND ...  159  522  574
# 7    01M650                               CASCADES HIGH SCHOOL   18  417  418
# 8    01M696                     BARD HIGH SCHOOL EARLY COLLEGE  130  624  604
# 9    02M047  47 THE AMERICAN SIGN LANGUAGE AND ENGLISH SECO...   16  395  400
# 10   02M288                       FOOD AND FINANCE HIGH SCHOOL   62  409  393
# ...
